# %%
#Import our dependencies and initialize counters and an empty list that will hold the weather data.
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import gmaps

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Defining weather API url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Adding the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Step3 : Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current description":city_description})

# #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | luderitz
# Processing Record 2 of Set 1 | comodoro rivadavia
# Processing Record 3 of Set 1 | grindavik
# Processing Record 4 of Set 1 | santa catalina
# Processing Record 5 of Set 1 | saint-medard-en-jalles
# Processing Record 6 of Set 1 | pastos bons
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | dapaong
# Processing Record 12 of Set 1 | klaksvik
# Processing Record 13 of Set 1 | ha tinh
# Processing Record 14 of Set 1 | sitka
# Processing Record 15 of Set 1 | yeppoon
# Processing Record 16 of Set 1 | vardo
# Processing Record 17 of Set 1 | kropotkin
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | takob
# City not found. Skipping...
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | serra talhada
# Processing Record 24 of Set 1 | normandin
# Processing Record 25 of Set 1 | egvekinot
# Processing Record 26 of Set 1 | torbay
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | vestbygda
# City not found. Skipping...
# Processing Record 32 of Set 1 | port hedland
# Processing Record 33 of Set 1 | ambon
# Processing Record 34 of Set 1 | hofn
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | kruisfontein
# Processing Record 39 of Set 1 | kendari
# Processing Record 40 of Set 1 | mayo
# Processing Record 41 of Set 1 | luanda
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | cabedelo
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | victoria
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 2 | champerico
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | tansen
# Processing Record 7 of Set 2 | narsaq
# Processing Record 8 of Set 2 | chokurdakh
# Processing Record 9 of Set 2 | cabo san lucas
# Processing Record 10 of Set 2 | waddan
# Processing Record 11 of Set 2 | dingle
# Processing Record 12 of Set 2 | izmir
# Processing Record 13 of Set 2 | faanui
# Processing Record 14 of Set 2 | kerman
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | north bend
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | san cristobal
# Processing Record 19 of Set 2 | ugoofaaru
# Processing Record 20 of Set 2 | villarrica
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | omsukchan
# Processing Record 23 of Set 2 | provideniya
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | siderno
# Processing Record 26 of Set 2 | asau
# Processing Record 27 of Set 2 | mar del plata
# Processing Record 28 of Set 2 | acari
# Processing Record 29 of Set 2 | unye
# City not found. Skipping...
# Processing Record 30 of Set 2 | beeville
# Processing Record 31 of Set 2 | khor
# Processing Record 32 of Set 2 | singkang
# Processing Record 33 of Set 2 | plettenberg bay
# Processing Record 34 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 2 | ryabovo
# Processing Record 36 of Set 2 | yar-sale
# Processing Record 37 of Set 2 | seoni
# Processing Record 38 of Set 2 | vila franca do campo
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | esperance
# Processing Record 42 of Set 2 | qasigiannguit
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | harper
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | kharp
# Processing Record 48 of Set 2 | seddon
# Processing Record 49 of Set 2 | pochutla
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | roma
# Processing Record 3 of Set 3 | knysna
# Processing Record 4 of Set 3 | carnarvon
# Processing Record 5 of Set 3 | saint-philippe
# Processing Record 6 of Set 3 | mehamn
# Processing Record 7 of Set 3 | ancud
# Processing Record 8 of Set 3 | clyde river
# Processing Record 9 of Set 3 | katherine
# Processing Record 10 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 3 | olafsvik
# Processing Record 12 of Set 3 | kaitangata
# Processing Record 13 of Set 3 | ordu
# Processing Record 14 of Set 3 | san juan
# Processing Record 15 of Set 3 | sal rei
# Processing Record 16 of Set 3 | cherskiy
# Processing Record 17 of Set 3 | strelka
# Processing Record 18 of Set 3 | bathsheba
# Processing Record 19 of Set 3 | airai
# Processing Record 20 of Set 3 | padang
# Processing Record 21 of Set 3 | meulaboh
# Processing Record 22 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 3 | lavrentiya
# Processing Record 24 of Set 3 | torva
# Processing Record 25 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 3 | flinders
# Processing Record 27 of Set 3 | tuatapere
# Processing Record 28 of Set 3 | saskylakh
# Processing Record 29 of Set 3 | gallup
# Processing Record 30 of Set 3 | owando
# Processing Record 31 of Set 3 | bilibino
# Processing Record 32 of Set 3 | onalaska
# Processing Record 33 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 3 | tazovskiy
# Processing Record 35 of Set 3 | vao
# Processing Record 36 of Set 3 | lapua
# Processing Record 37 of Set 3 | puerto cortes
# City not found. Skipping...
# Processing Record 38 of Set 3 | leningradskiy
# Processing Record 39 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 3 | isla vista
# Processing Record 41 of Set 3 | belyy yar
# Processing Record 42 of Set 3 | bambous virieux
# Processing Record 43 of Set 3 | dukat
# Processing Record 44 of Set 3 | sao joao da barra
# Processing Record 45 of Set 3 | petrozavodsk
# Processing Record 46 of Set 3 | iquique
# Processing Record 47 of Set 3 | berwick
# Processing Record 48 of Set 3 | duz
# City not found. Skipping...
# Processing Record 49 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 3 | arraial do cabo
# Processing Record 1 of Set 4 | georgetown
# Processing Record 2 of Set 4 | chilca
# Processing Record 3 of Set 4 | huangchuan
# Processing Record 4 of Set 4 | port hueneme
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | luwuk
# Processing Record 7 of Set 4 | westport
# Processing Record 8 of Set 4 | nikolskoye
# Processing Record 9 of Set 4 | killybegs
# Processing Record 10 of Set 4 | lompoc
# Processing Record 11 of Set 4 | san carlos de bariloche
# Processing Record 12 of Set 4 | nishihara
# Processing Record 13 of Set 4 | jamestown
# Processing Record 14 of Set 4 | constitucion
# Processing Record 15 of Set 4 | jalu
# Processing Record 16 of Set 4 | vilhena
# Processing Record 17 of Set 4 | touros
# Processing Record 18 of Set 4 | shevchenkove
# Processing Record 19 of Set 4 | am timan
# Processing Record 20 of Set 4 | zapolyarnyy
# Processing Record 21 of Set 4 | nantucket
# Processing Record 22 of Set 4 | caxito
# Processing Record 23 of Set 4 | pavelets
# Processing Record 24 of Set 4 | segezha
# Processing Record 25 of Set 4 | lorengau
# Processing Record 26 of Set 4 | xining
# Processing Record 27 of Set 4 | lima
# Processing Record 28 of Set 4 | tuktoyaktuk
# Processing Record 29 of Set 4 | college
# Processing Record 30 of Set 4 | port blair
# Processing Record 31 of Set 4 | srednekolymsk
# Processing Record 32 of Set 4 | husavik
# Processing Record 33 of Set 4 | englewood
# Processing Record 34 of Set 4 | tabira
# Processing Record 35 of Set 4 | hamilton
# Processing Record 36 of Set 4 | tautira
# Processing Record 37 of Set 4 | hilo
# Processing Record 38 of Set 4 | dawson creek
# Processing Record 39 of Set 4 | dahra
# Processing Record 40 of Set 4 | havre-saint-pierre
# Processing Record 41 of Set 4 | semme
# Processing Record 42 of Set 4 | clifton
# Processing Record 43 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 4 | lebu
# Processing Record 45 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 4 | kodiak
# Processing Record 47 of Set 4 | pisco
# Processing Record 48 of Set 4 | rio pardo
# Processing Record 49 of Set 4 | ust-nera
# Processing Record 50 of Set 4 | riga
# Processing Record 1 of Set 5 | pevek
# Processing Record 2 of Set 5 | novikovo
# Processing Record 3 of Set 5 | divnogorsk
# Processing Record 4 of Set 5 | east london
# Processing Record 5 of Set 5 | kysyl-syr
# Processing Record 6 of Set 5 | acajutla
# Processing Record 7 of Set 5 | salinas
# Processing Record 8 of Set 5 | morondava
# Processing Record 9 of Set 5 | sao filipe
# Processing Record 10 of Set 5 | kabale
# Processing Record 11 of Set 5 | muravlenko
# Processing Record 12 of Set 5 | huarmey
# Processing Record 13 of Set 5 | inta
# Processing Record 14 of Set 5 | namatanai
# Processing Record 15 of Set 5 | poum
# Processing Record 16 of Set 5 | rabo de peixe
# Processing Record 17 of Set 5 | nador
# Processing Record 18 of Set 5 | bairiki
# Processing Record 19 of Set 5 | port hardy
# Processing Record 20 of Set 5 | vila velha
# Processing Record 21 of Set 5 | sola
# Processing Record 22 of Set 5 | tiksi
# Processing Record 23 of Set 5 | port elizabeth
# Processing Record 24 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 25 of Set 5 | douentza
# Processing Record 26 of Set 5 | riyadh
# Processing Record 27 of Set 5 | okitipupa
# Processing Record 28 of Set 5 | quatre cocos
# Processing Record 29 of Set 5 | valparaiso
# Processing Record 30 of Set 5 | acapulco
# Processing Record 31 of Set 5 | laguna
# Processing Record 32 of Set 5 | scalloway
# City not found. Skipping...
# Processing Record 33 of Set 5 | avera
# Processing Record 34 of Set 5 | thinadhoo
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | stepnyak
# Processing Record 37 of Set 5 | smoky lake
# Processing Record 38 of Set 5 | mehriz
# Processing Record 39 of Set 5 | haimen
# Processing Record 40 of Set 5 | yenagoa
# Processing Record 41 of Set 5 | port augusta
# Processing Record 42 of Set 5 | boende
# Processing Record 43 of Set 5 | dzaoudzi
# Processing Record 44 of Set 5 | sept-iles
# Processing Record 45 of Set 5 | hauterive
# Processing Record 46 of Set 5 | toguchin
# Processing Record 47 of Set 5 | chama
# Processing Record 48 of Set 5 | saint-georges
# Processing Record 49 of Set 5 | port lincoln
# Processing Record 50 of Set 5 | amuntai
# Processing Record 1 of Set 6 | kingaroy
# Processing Record 2 of Set 6 | smithers
# Processing Record 3 of Set 6 | pangnirtung
# Processing Record 4 of Set 6 | camacupa
# Processing Record 5 of Set 6 | broome
# Processing Record 6 of Set 6 | mufumbwe
# Processing Record 7 of Set 6 | strathmore
# Processing Record 8 of Set 6 | sande
# Processing Record 9 of Set 6 | pyshma
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 12 of Set 6 | lisbon
# Processing Record 13 of Set 6 | chuy
# Processing Record 14 of Set 6 | biograd na moru
# Processing Record 15 of Set 6 | cidreira
# Processing Record 16 of Set 6 | bilma
# Processing Record 17 of Set 6 | nyurba
# Processing Record 18 of Set 6 | solnechnyy
# Processing Record 19 of Set 6 | nitra
# Processing Record 20 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 6 | lyuban
# Processing Record 22 of Set 6 | kapoeta
# Processing Record 23 of Set 6 | komsomolskiy
# Processing Record 24 of Set 6 | rocha
# Processing Record 25 of Set 6 | holme
# Processing Record 26 of Set 6 | ulaanbaatar
# Processing Record 27 of Set 6 | miyako
# Processing Record 28 of Set 6 | saldanha
# Processing Record 29 of Set 6 | atambua
# Processing Record 30 of Set 6 | beloha
# Processing Record 31 of Set 6 | bafut
# Processing Record 32 of Set 6 | bac lieu
# Processing Record 33 of Set 6 | hirara
# Processing Record 34 of Set 6 | banda aceh
# Processing Record 35 of Set 6 | saint-joseph
# Processing Record 36 of Set 6 | saint-augustin
# Processing Record 37 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 6 | cayenne
# Processing Record 39 of Set 6 | sao jose da coroa grande
# Processing Record 40 of Set 6 | tarko-sale
# Processing Record 41 of Set 6 | lata
# Processing Record 42 of Set 6 | ikungi
# Processing Record 43 of Set 6 | karratha
# Processing Record 44 of Set 6 | lardos
# Processing Record 45 of Set 6 | yandyki
# Processing Record 46 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 6 | tondi
# Processing Record 48 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 6 | iqaluit
# Processing Record 50 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 7 | hay river
# Processing Record 2 of Set 7 | aklavik
# Processing Record 3 of Set 7 | sao sebastiao
# Processing Record 4 of Set 7 | pafos
# Processing Record 5 of Set 7 | salamanca
# Processing Record 6 of Set 7 | hobyo
# Processing Record 7 of Set 7 | yulara
# Processing Record 8 of Set 7 | liyang
# Processing Record 9 of Set 7 | nome
# Processing Record 10 of Set 7 | inongo
# Processing Record 11 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 7 | catalina
# Processing Record 13 of Set 7 | islamkot
# Processing Record 14 of Set 7 | almaznyy
# Processing Record 15 of Set 7 | horsham
# Processing Record 16 of Set 7 | fortuna
# Processing Record 17 of Set 7 | muros
# Processing Record 18 of Set 7 | deniliquin
# Processing Record 19 of Set 7 | belmonte
# Processing Record 20 of Set 7 | la ronge
# Processing Record 21 of Set 7 | phumi samraong
# City not found. Skipping...
# Processing Record 22 of Set 7 | mount isa
# Processing Record 23 of Set 7 | te anau
# Processing Record 24 of Set 7 | cozumel
# Processing Record 25 of Set 7 | nouadhibou
# Processing Record 26 of Set 7 | carutapera
# Processing Record 27 of Set 7 | oktyabrskiy
# Processing Record 28 of Set 7 | cockburn town
# Processing Record 29 of Set 7 | ulladulla
# Processing Record 30 of Set 7 | san jeronimo
# Processing Record 31 of Set 7 | salalah
# Processing Record 32 of Set 7 | sulangan
# Processing Record 33 of Set 7 | spassk-ryazanskiy
# Processing Record 34 of Set 7 | juba
# Processing Record 35 of Set 7 | codrington
# Processing Record 36 of Set 7 | geraldton
# Processing Record 37 of Set 7 | mount gambier
# Processing Record 38 of Set 7 | zabaykalsk
# Processing Record 39 of Set 7 | hastings
# Processing Record 40 of Set 7 | bengkulu
# Processing Record 41 of Set 7 | inuvik
# Processing Record 42 of Set 7 | san ramon
# Processing Record 43 of Set 7 | longyearbyen
# Processing Record 44 of Set 7 | takestan
# Processing Record 45 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 46 of Set 7 | bayanday
# Processing Record 47 of Set 7 | sterling
# Processing Record 48 of Set 7 | klyuchi
# Processing Record 49 of Set 7 | anadyr
# Processing Record 50 of Set 7 | kirakira
# Processing Record 1 of Set 8 | chojnow
# Processing Record 2 of Set 8 | abu dhabi
# Processing Record 3 of Set 8 | kursk
# Processing Record 4 of Set 8 | norman wells
# Processing Record 5 of Set 8 | alihe
# Processing Record 6 of Set 8 | birao
# Processing Record 7 of Set 8 | beringovskiy
# Processing Record 8 of Set 8 | kautokeino
# Processing Record 9 of Set 8 | farmington
# Processing Record 10 of Set 8 | tilichiki
# Processing Record 11 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 8 | sartell
# Processing Record 13 of Set 8 | spartanburg
# Processing Record 14 of Set 8 | ribeira grande
# Processing Record 15 of Set 8 | taltal
# Processing Record 16 of Set 8 | uusikaupunki
# Processing Record 17 of Set 8 | fukue
# Processing Record 18 of Set 8 | mumbwa
# Processing Record 19 of Set 8 | atar
# Processing Record 20 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 8 | shitanjing
# Processing Record 22 of Set 8 | bam
# Processing Record 23 of Set 8 | kosh-agach
# Processing Record 24 of Set 8 | samarai
# Processing Record 25 of Set 8 | lagoa
# Processing Record 26 of Set 8 | aksu
# Processing Record 27 of Set 8 | rota
# Processing Record 28 of Set 8 | aksarka
# Processing Record 29 of Set 8 | sechura
# Processing Record 30 of Set 8 | jiayuguan
# Processing Record 31 of Set 8 | kidal
# Processing Record 32 of Set 8 | kindu
# Processing Record 33 of Set 8 | labuhan
# Processing Record 34 of Set 8 | braganca
# Processing Record 35 of Set 8 | wad madani
# Processing Record 36 of Set 8 | hasaki
# Processing Record 37 of Set 8 | svetlogorsk
# Processing Record 38 of Set 8 | freeport
# Processing Record 39 of Set 8 | sikasso
# Processing Record 40 of Set 8 | cravo norte
# Processing Record 41 of Set 8 | puerto rondon
# Processing Record 42 of Set 8 | chiredzi
# Processing Record 43 of Set 8 | kerouane
# Processing Record 44 of Set 8 | novougolnyy
# City not found. Skipping...
# Processing Record 45 of Set 8 | lora del rio
# Processing Record 46 of Set 8 | kangaatsiaq
# Processing Record 47 of Set 8 | woodward
# Processing Record 48 of Set 8 | sorland
# Processing Record 49 of Set 8 | tarauaca
# Processing Record 50 of Set 8 | dwarka
# Processing Record 1 of Set 9 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 9 | goderich
# Processing Record 3 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 9 | tortoli
# Processing Record 5 of Set 9 | richards bay
# Processing Record 6 of Set 9 | severo-yeniseyskiy
# Processing Record 7 of Set 9 | arecibo
# Processing Record 8 of Set 9 | yashalta
# Processing Record 9 of Set 9 | bandar
# Processing Record 10 of Set 9 | skjervoy
# Processing Record 11 of Set 9 | los pozos
# Processing Record 12 of Set 9 | ontario
# Processing Record 13 of Set 9 | marsh harbour
# Processing Record 14 of Set 9 | poya
# Processing Record 15 of Set 9 | torres
# Processing Record 16 of Set 9 | kadoshkino
# Processing Record 17 of Set 9 | penzance
# Processing Record 18 of Set 9 | daru
# Processing Record 19 of Set 9 | panzhihua
# Processing Record 20 of Set 9 | kemijarvi
# Processing Record 21 of Set 9 | sibolga
# Processing Record 22 of Set 9 | zonguldak
# Processing Record 23 of Set 9 | horki
# Processing Record 24 of Set 9 | tura
# Processing Record 25 of Set 9 | muli
# Processing Record 26 of Set 9 | brae
# Processing Record 27 of Set 9 | mounana
# Processing Record 28 of Set 9 | whitianga
# Processing Record 29 of Set 9 | northam
# Processing Record 30 of Set 9 | hovd
# Processing Record 31 of Set 9 | itarema
# Processing Record 32 of Set 9 | nuuk
# Processing Record 33 of Set 9 | rorvik
# Processing Record 34 of Set 9 | miles city
# Processing Record 35 of Set 9 | djougou
# Processing Record 36 of Set 9 | fondi
# Processing Record 37 of Set 9 | lahaina
# Processing Record 38 of Set 9 | tianpeng
# Processing Record 39 of Set 9 | kathu
# Processing Record 40 of Set 9 | vryburg
# Processing Record 41 of Set 9 | biak
# Processing Record 42 of Set 9 | lere
# Processing Record 43 of Set 9 | maraa
# Processing Record 44 of Set 9 | dunedin
# Processing Record 45 of Set 9 | axim
# Processing Record 46 of Set 9 | palamos
# Processing Record 47 of Set 9 | faya
# Processing Record 48 of Set 9 | mitu
# Processing Record 49 of Set 9 | kandrian
# Processing Record 50 of Set 9 | rio grande
# Processing Record 1 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 10 | shingu
# Processing Record 3 of Set 10 | saint george
# Processing Record 4 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 10 | akyab
# Processing Record 6 of Set 10 | yendi
# Processing Record 7 of Set 10 | alice springs
# Processing Record 8 of Set 10 | zhoucheng
# Processing Record 9 of Set 10 | half moon bay
# Processing Record 10 of Set 10 | stephenville
# Processing Record 11 of Set 10 | namibe
# Processing Record 12 of Set 10 | harnosand
# Processing Record 13 of Set 10 | bosaso
# Processing Record 14 of Set 10 | amapa
# Processing Record 15 of Set 10 | henties bay
# Processing Record 16 of Set 10 | tampere
# Processing Record 17 of Set 10 | biu
# Processing Record 18 of Set 10 | mackay
# Processing Record 19 of Set 10 | labytnangi
# Processing Record 20 of Set 10 | manacapuru
# Processing Record 21 of Set 10 | nexo
# Processing Record 22 of Set 10 | gamba
# Processing Record 23 of Set 10 | tanete
# Processing Record 24 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 25 of Set 10 | newport
# Processing Record 26 of Set 10 | naze
# Processing Record 27 of Set 10 | makakilo city
# Processing Record 28 of Set 10 | puerto madryn
# Processing Record 29 of Set 10 | placido de castro
# Processing Record 30 of Set 10 | edd
# Processing Record 31 of Set 10 | ganzhou
# Processing Record 32 of Set 10 | lagos
# Processing Record 33 of Set 10 | nerekhta
# Processing Record 34 of Set 10 | gloucester
# Processing Record 35 of Set 10 | manta
# Processing Record 36 of Set 10 | bandarbeyla
# Processing Record 37 of Set 10 | antalya
# Processing Record 38 of Set 10 | ixtapa
# Processing Record 39 of Set 10 | amlame
# Processing Record 40 of Set 10 | san andres
# Processing Record 41 of Set 10 | kamina
# Processing Record 42 of Set 10 | lucapa
# Processing Record 43 of Set 10 | finnsnes
# Processing Record 44 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 45 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 46 of Set 10 | walvis bay
# Processing Record 47 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 48 of Set 10 | farafangana
# Processing Record 49 of Set 10 | huntley
# Processing Record 50 of Set 10 | zverinogolovskoye
# Processing Record 1 of Set 11 | wajir
# Processing Record 2 of Set 11 | sint-truiden
# Processing Record 3 of Set 11 | hambantota
# Processing Record 4 of Set 11 | evensk
# Processing Record 5 of Set 11 | fuyu
# Processing Record 6 of Set 11 | moissala
# Processing Record 7 of Set 11 | elat
# Processing Record 8 of Set 11 | estelle
# Processing Record 9 of Set 11 | stornoway
# Processing Record 10 of Set 11 | camacha
# Processing Record 11 of Set 11 | talnakh
# Processing Record 12 of Set 11 | makat
# Processing Record 13 of Set 11 | matagami
# Processing Record 14 of Set 11 | gimbi
# Processing Record 15 of Set 11 | farad
# Processing Record 16 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 11 | monzon
# Processing Record 18 of Set 11 | tessalit
# Processing Record 19 of Set 11 | si bun ruang
# Processing Record 20 of Set 11 | vostok
# Processing Record 21 of Set 11 | nelson bay
# Processing Record 22 of Set 11 | creston
# Processing Record 23 of Set 11 | campos belos
# Processing Record 24 of Set 11 | orlik
# Processing Record 25 of Set 11 | bonga
# Processing Record 26 of Set 11 | akdepe
# Processing Record 27 of Set 11 | dafeng
# Processing Record 28 of Set 11 | peniche
# Processing Record 29 of Set 11 | okha
# Processing Record 30 of Set 11 | katsuura
# Processing Record 31 of Set 11 | oistins
# Processing Record 32 of Set 11 | sabang
# Processing Record 33 of Set 11 | pauini
# Processing Record 34 of Set 11 | kibala
# Processing Record 35 of Set 11 | kutum
# Processing Record 36 of Set 11 | cavalcante
# Processing Record 37 of Set 11 | khandyga
# Processing Record 38 of Set 11 | young
# Processing Record 39 of Set 11 | garowe
# Processing Record 40 of Set 11 | opuwo
# Processing Record 41 of Set 11 | suntar
# Processing Record 42 of Set 11 | udachnyy
# Processing Record 43 of Set 11 | mpongwe
# Processing Record 44 of Set 11 | yanam
# Processing Record 45 of Set 11 | moissac
# Processing Record 46 of Set 11 | coquimbo
# Processing Record 47 of Set 11 | omutinskoye
# City not found. Skipping...
# Processing Record 48 of Set 11 | shimoda
# Processing Record 49 of Set 11 | mogadishu
# Processing Record 50 of Set 11 | bani walid
# Processing Record 1 of Set 12 | turukhansk
# Processing Record 2 of Set 12 | san patricio
# Processing Record 3 of Set 12 | tecoanapa
# Processing Record 4 of Set 12 | zavoronezhskoye
# Processing Record 5 of Set 12 | riaba
# City not found. Skipping...
# Processing Record 6 of Set 12 | ojdula
# Processing Record 7 of Set 12 | moerai
# Processing Record 8 of Set 12 | novaya zaimka
# Processing Record 9 of Set 12 | lasa
# Processing Record 10 of Set 12 | abu samrah
# Processing Record 11 of Set 12 | san quintin
# Processing Record 12 of Set 12 | portland
# Processing Record 13 of Set 12 | tarazona
# Processing Record 14 of Set 12 | nagornyy
# Processing Record 15 of Set 12 | sioux lookout
# Processing Record 16 of Set 12 | balykshi
# Processing Record 17 of Set 12 | batemans bay
# Processing Record 18 of Set 12 | praia
# Processing Record 19 of Set 12 | kavaratti
# Processing Record 20 of Set 12 | jinka
# Processing Record 21 of Set 12 | verkhnyaya inta
# Processing Record 22 of Set 12 | salto del guaira
# Processing Record 23 of Set 12 | martapura
# Processing Record 24 of Set 12 | derzhavinsk
# Processing Record 25 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 26 of Set 12 | saucillo
# Processing Record 27 of Set 12 | hvammstangi
# City not found. Skipping...
# Processing Record 28 of Set 12 | arica
# Processing Record 29 of Set 12 | corinto
# Processing Record 30 of Set 12 | hualmay
# Processing Record 31 of Set 12 | sosnovka
# Processing Record 32 of Set 12 | kulhudhuffushi
# Processing Record 33 of Set 12 | emmett
# Processing Record 34 of Set 12 | botucatu
# Processing Record 35 of Set 12 | catuday
# Processing Record 36 of Set 12 | campo maior
# Processing Record 37 of Set 12 | batagay-alyta
# Processing Record 38 of Set 12 | wembley
# Processing Record 39 of Set 12 | sungairaya
# Processing Record 40 of Set 12 | harlingen
# Processing Record 41 of Set 12 | sauce
# Processing Record 42 of Set 12 | sinjar
# Processing Record 43 of Set 12 | toora-khem
# Processing Record 44 of Set 12 | neftcala
# Processing Record 45 of Set 12 | kathmandu
# Processing Record 46 of Set 12 | manokwari
# Processing Record 47 of Set 12 | chara
# Processing Record 48 of Set 12 | petrovsk-zabaykalskiy
# Processing Record 49 of Set 12 | kungur
# Processing Record 50 of Set 12 | lidkoping
# Processing Record 1 of Set 13 | roebourne
# Processing Record 2 of Set 13 | bharatpur
# Processing Record 3 of Set 13 | coahuayana
# Processing Record 4 of Set 13 | berlevag
# Processing Record 5 of Set 13 | warwick
# Processing Record 6 of Set 13 | bull savanna
# Processing Record 7 of Set 13 | yoichi
# Processing Record 8 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 13 | uruzgan
# Processing Record 10 of Set 13 | dali
# Processing Record 11 of Set 13 | punta alta
# Processing Record 12 of Set 13 | waverly
# Processing Record 13 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 13 | masuguru
# Processing Record 15 of Set 13 | alofi
# Processing Record 16 of Set 13 | kapit
# Processing Record 17 of Set 13 | springbok
# Processing Record 18 of Set 13 | matara
# Processing Record 19 of Set 13 | camocim
# Processing Record 20 of Set 13 | camana
# Processing Record 21 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 13 | whitehorse
# Processing Record 23 of Set 13 | kumluca
# Processing Record 24 of Set 13 | sakakah
# Processing Record 25 of Set 13 | kigoma
# Processing Record 26 of Set 13 | aloleng
# Processing Record 27 of Set 13 | mastic beach
# Processing Record 28 of Set 13 | grand gaube
# Processing Record 29 of Set 13 | ulaangom
# Processing Record 30 of Set 13 | penalva
# Processing Record 31 of Set 13 | belaya gora
# Processing Record 32 of Set 13 | sawtell
# Processing Record 33 of Set 13 | rio gallegos
# Processing Record 34 of Set 13 | ciudad bolivar
# Processing Record 35 of Set 13 | roald
# Processing Record 36 of Set 13 | marsa matruh
# Processing Record 37 of Set 13 | amalapuram
# Processing Record 38 of Set 13 | houston
# Processing Record 39 of Set 13 | yataity
# Processing Record 40 of Set 13 | senanga
# Processing Record 41 of Set 13 | gunnedah
# Processing Record 42 of Set 13 | ngorongoro
# Processing Record 43 of Set 13 | glendive
# Processing Record 44 of Set 13 | ketchikan
# Processing Record 45 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 13 | kanniyakumari
# Processing Record 47 of Set 13 | iskateley
# Processing Record 48 of Set 13 | isangel
# Processing Record 49 of Set 13 | asyut
# Processing Record 50 of Set 13 | krasnoshchekovo
# Processing Record 1 of Set 14 | port macquarie
# Processing Record 2 of Set 14 | cap malheureux
# Processing Record 3 of Set 14 | zhangye
# Processing Record 4 of Set 14 | baherden
# Processing Record 5 of Set 14 | quebo
# Processing Record 6 of Set 14 | zatoka
# Processing Record 7 of Set 14 | anori
# Processing Record 8 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 9 of Set 14 | sabya
# Processing Record 10 of Set 14 | ucluelet
# Processing Record 11 of Set 14 | salumbar
# Processing Record 12 of Set 14 | sinnamary
# Processing Record 13 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 14 | palana
# Processing Record 15 of Set 14 | moyale
# Processing Record 16 of Set 14 | vestmannaeyjar
# Processing Record 17 of Set 14 | kenai
# Processing Record 18 of Set 14 | yanggu
# Processing Record 19 of Set 14 | hirtshals
# Processing Record 20 of Set 14 | atasu
# Processing Record 21 of Set 14 | rawlins
# Processing Record 22 of Set 14 | cam ranh
# Processing Record 23 of Set 14 | turochak
# Processing Record 24 of Set 14 | christchurch
# Processing Record 25 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 26 of Set 14 | hibbing
# Processing Record 27 of Set 14 | taunggyi
# Processing Record 28 of Set 14 | aykhal
# Processing Record 29 of Set 14 | manado
# Processing Record 30 of Set 14 | mafeteng
# Processing Record 31 of Set 14 | sao felix do xingu
# Processing Record 32 of Set 14 | mahebourg
# Processing Record 33 of Set 14 | mayumba
# Processing Record 34 of Set 14 | drochtersen
# Processing Record 35 of Set 14 | kalat
# Processing Record 36 of Set 14 | farafenni
# Processing Record 37 of Set 14 | bagdarin
# Processing Record 38 of Set 14 | omidiyeh
# Processing Record 39 of Set 14 | ahipara
# Processing Record 40 of Set 14 | abu zabad
# Processing Record 41 of Set 14 | imbituba
# Processing Record 42 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 14 | aswan
# Processing Record 44 of Set 14 | aquiraz
# Processing Record 45 of Set 14 | gympie
# Processing Record 46 of Set 14 | nouakchott
# Processing Record 47 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 48 of Set 14 | leshukonskoye
# Processing Record 49 of Set 14 | xai-xai
# Processing Record 50 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 1 of Set 15 | erenhot
# Processing Record 2 of Set 15 | maldonado
# Processing Record 3 of Set 15 | chengde
# Processing Record 4 of Set 15 | porto velho
# Processing Record 5 of Set 15 | villeneuve-sur-lot
# Processing Record 6 of Set 15 | kailua
# Processing Record 7 of Set 15 | loikaw
# Processing Record 8 of Set 15 | vanimo
# Processing Record 9 of Set 15 | nioro
# Processing Record 10 of Set 15 | pingxiang
# Processing Record 11 of Set 15 | sosva
# Processing Record 12 of Set 15 | jedburgh
# Processing Record 13 of Set 15 | tynda
# Processing Record 14 of Set 15 | hami
# Processing Record 15 of Set 15 | antofagasta
# Processing Record 16 of Set 15 | abha
# Processing Record 17 of Set 15 | opunake
# Processing Record 18 of Set 15 | shambu
# Processing Record 19 of Set 15 | homer
# Processing Record 20 of Set 15 | zhigalovo
# Processing Record 21 of Set 15 | marathon
# Processing Record 22 of Set 15 | akure
# Processing Record 23 of Set 15 | zhezkazgan
# Processing Record 24 of Set 15 | bambanglipuro
# Processing Record 25 of Set 15 | kampot
# Processing Record 26 of Set 15 | nea alikarnassos
# Processing Record 27 of Set 15 | luzhany
# Processing Record 28 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 30 of Set 15 | abu kamal
# Processing Record 31 of Set 15 | ourossogui
# Processing Record 32 of Set 15 | hervey bay
# Processing Record 33 of Set 15 | chunskiy
# Processing Record 34 of Set 15 | a
# City not found. Skipping...
# Processing Record 35 of Set 15 | athabasca
# Processing Record 36 of Set 15 | kiama
# Processing Record 37 of Set 15 | moroni
# Processing Record 38 of Set 15 | mnogovershinnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 681

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0                  Luderitz      NA -26.6481   15.1594     77.56        47
# 1        Comodoro Rivadavia      AR -45.8667  -67.5000     71.60        60
# 2                 Grindavik      IS  63.8424  -22.4338     30.20        86
# 3            Santa Catalina      PH   9.3337  122.8637     80.60        83
# 4    Saint-Medard-En-Jalles      FR  44.8969   -0.7214     57.00        58
# ..                      ...     ...      ...       ...       ...       ...
# 676                Chunskiy      RU  56.0815   99.6342      4.87        93
# 677               Athabasca      CA  54.7169 -113.2854     19.40        79
# 678                   Kiama      AU -34.6833  150.8667     64.00        84
# 679                  Moroni      KM -11.7022   43.2551     83.25        72
# 680         Mnogovershinnyy      RU  53.9353  139.9242    -21.98        82
#
#      Cloudiness  Wind Speed Current description
# 0             0       29.62           clear sky
# 1            75        4.61       broken clouds
# 2            75       26.46       broken clouds
# 3            75        6.91       broken clouds
# 4             0        5.75           clear sky
# ..          ...         ...                 ...
# 676         100        7.63     overcast clouds
# 677         100        4.61     overcast clouds
# 678         100        1.99          light rain
# 679         100        8.34     overcast clouds
# 680          99        8.37     overcast clouds
#
# [681 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
